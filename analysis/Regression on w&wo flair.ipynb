# %%
library(stargazer)
# Out:
# Please cite as:
#
#
#  Hlavac, Marek (2022). stargazer: Well-Formatted Regression and Summary Statistics Tables.
#
#  R package version 5.2.3. https://CRAN.R-project.org/package=stargazer

# %%
options(width=80)

# %%
path <- ""
data <- read.csv(path)

# %%
data
# Out:
#       title         is_title_visible subreddit     perc_alignment
# 1     Psychologist  True             psychotherapy 1.0000000
# 2     Psychologist  True             psychotherapy 0.8333333
# 3     Psychologist  True             psychotherapy 0.7142857
# 4     Psychologist  True             psychotherapy 1.0000000
# 5     Psychologist  False            MomForAMinute 0.3333333
# 6     Psychologist  False            MomForAMinute 0.6363636
# 7     Psychologist  False            MomForAMinute 0.5000000
# 8     Psychologist  False            MomForAMinute 0.4166667
# 9     Psychologist  False            MomForAMinute 0.1000000
# 10    Psychologist  False            MomForAMinute 0.8461538
# 11    Psychologist  True             psychotherapy 0.7222222
# 12    Psychologist  True             psychotherapy 0.9375000
# 13    Therapist     True             psychotherapy 0.6666667
# 14    Therapist     True             psychotherapy 0.6666667
# ...

# %%
model <- lm(perc_alignment ~ as.factor(title) + is_title_visible + as.factor(subreddit), data=data)

# %%
summary(model)
# Out:
# Call:
# lm(formula = perc_alignment ~ as.factor(title) + is_title_visible +
#     as.factor(subreddit), data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.78707 -0.15955  0.05506  0.21293  0.62918
#
# Coefficients:
#                                            Estimate Std. Error t value Pr(>|t|)
# (Intercept)                                0.527349   0.104424   5.050 4.46e-07
# as.factor(title)Funeral Role               0.121068   0.097460   1.242  0.21417
# as.factor(title)Medical Doctor             0.028427   0.018499   1.537  0.12439
# as.factor(title)Nurse                      0.060227   0.057799   1.042  0.29742
# as.factor(title)Psychiatrist               0.008142   0.016543   0.492  0.62258
# as.factor(title)Psychologist              -0.002394   0.007645  -0.313  0.75415
# as.factor(title)Social Worker              0.010557   0.005995   1.761  0.07825
# as.factor(title)Therapist                 -0.001979   0.005391  -0.367  0.71362
# ...

# %%
summary(model)
# Out:
# Call:
# lm(formula = perc_alignment ~ as.factor(title) + is_title_visible +
#     as.factor(subreddit), data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.78707 -0.15955  0.05506  0.21293  0.62918
#
# Coefficients:
#                                            Estimate Std. Error t value Pr(>|t|)
# (Intercept)                                0.527349   0.104424   5.050 4.46e-07
# as.factor(title)Funeral Role               0.121068   0.097460   1.242  0.21417
# as.factor(title)Medical Doctor             0.028427   0.018499   1.537  0.12439
# as.factor(title)Nurse                      0.060227   0.057799   1.042  0.29742
# as.factor(title)Psychiatrist               0.008142   0.016543   0.492  0.62258
# as.factor(title)Psychologist              -0.002394   0.007645  -0.313  0.75415
# as.factor(title)Social Worker              0.010557   0.005995   1.761  0.07825
# as.factor(title)Therapist                 -0.001979   0.005391  -0.367  0.71362
# ...

# %%
stargazer(model, single.row=TRUE)
# Out:
# % Table created by stargazer v.5.2.3 by Marek Hlavac, Social Policy Institute. E-mail: marek.hlavac at gmail.com
# % Date and time: Mon, Dec 11, 2023 - 04:00:00 PM
# \begin{table}[!htbp] \centering
#   \caption{}
#   \label{}
# \begin{tabular}{@{\extracolsep{5pt}}lc}
# \\[-1.8ex]\hline
# \hline \\[-1.8ex]
#  & \multicolumn{1}{c}{\textit{Dependent variable:}} \\
# \cline{2-2}
# \\[-1.8ex] & perc\_alignment \\
# \hline \\[-1.8ex]
#  as.factor(title)Funeral Role & 0.121 (0.097) \\
#   as.factor(title)Medical Doctor & 0.028 (0.018) \\
#   as.factor(title)Nurse & 0.060 (0.058) \\
#   as.factor(title)Psychiatrist & 0.008 (0.017) \\
#   as.factor(title)Psychologist & $-$0.002 (0.008) \\
#   as.factor(title)Social Worker & 0.011$^{*}$ (0.006) \\
#   as.factor(title)Therapist & $-$0.002 (0.005) \\
#   is\_title\_visibleTrue & 0.027$^{***}$ (0.009) \\
#   as.factor(subreddit)adultsurvivors & 0.045 (0.107) \\
#   as.factor(subreddit)Advice & 0.204$^{*}$ (0.106) \\
# ...
